# %%
n, t= var('n, t')
integrate(t^n, t)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File ~/miniconda3/envs/sage/lib/python3.11/site-packages/sage/interfaces/maxima_lib.py:800, in MaximaLib.sr_integral(self, *args)
#     799 try:
# --> 800     return max_to_sr(maxima_eval(([max_integrate],
#     801                                   [sr_to_max(SR(a)) for a in args])))
#     802 except RuntimeError as error:
#
# File ~/miniconda3/envs/sage/lib/python3.11/site-packages/sage/libs/ecl.pyx:828, in sage.libs.ecl.EclObject.__call__ (build/cythonized/sage/libs/ecl.c:12227)()
#     827 lispargs = EclObject(list(args))
# --> 828 return ecl_wrap(ecl_safe_apply(self.obj, (<EclObject>lispargs).obj))
#     829
#
# File ~/miniconda3/envs/sage/lib/python3.11/site-packages/sage/libs/ecl.pyx:356, in sage.libs.ecl.ecl_safe_apply (build/cythonized/sage/libs/ecl.c:9731)()
#     355     else:
# ...
