# %% [markdown]
# # Chapter 1 - Notes

# %%
import os

proj = os.environ.get("QUARTO_PROJECT_DIR")

print("proj:", proj)

if proj is None:
    # interactive / notebook execution
    here = os.getcwd()
    print("here", here)
    proj = os.path.abspath(os.path.join(here, "..", ".."))
    print("proj:", proj)

    

load(os.path.join(proj, "_code", "sage_helpers.sage"))
# Out:
# proj: None
# here /home/igor/Documents/notebooks/cs/scientific-and-symbolic-computing-software/sage/bard
# proj: /home/igor/Documents/notebooks/cs/scientific-and-symbolic-computing-software

# %%
qshow(solve(x^2 - 16 == 0, x))
# Out:
# $$ \left[x = \left(-4\right), x = 4\right] $$

# %%
var('a b c')
qshow(solve(a*x**2 + b*x + c == 0, x))
# Out:
# $$ \left[x = -\frac{b + \sqrt{b^{2} - 4 \, a c}}{2 \, a}, x = -\frac{b - \sqrt{b^{2} - 4 \, a c}}{2 \, a}\right] $$

# %%
import os, json
from pathlib import Path
from IPython.display import Image, display

def quarto_target_format():
    info_path = os.environ.get("QUARTO_EXECUTE_INFO")
    if not info_path:
        return None  # running interactively, not via `quarto render`
    with open(info_path, "r", encoding="utf-8") as f:
        info = json.load(f)
    return info["format"]["identifier"]["target-format"], info


info_path = os.environ.get("QUARTO_EXECUTE_INFO")
print(info_path)
target, info = quarto_target_format() or ("html", None)
# print(target, info)
# # choose a stable place to write the png:
# # if Quarto is rendering, use the notebook's directory (from execute info)
# doc_dir = Path(info["document-path"]).parent if info else Path.cwd()
# png = doc_dir / "plot3d-fallback2.png"

g = sin(x*y)
p = plot3d(g, (x, -3, 3), (y, -3, 3))

# if target == "html":
#     p  # interactive
# else:
#     p.save(str(png), viewer="tachyon")
#     display(Image(filename=str(png)))

p.save("plot3d-interactive.html")
# Out:
# None

# %% [markdown]
# :::{.content-visible when-format="html"}
# this is the html
# <iframe src="plot3d-interactive.html" style="width:100%; height:520px; border:0;"></iframe>
# :::
#
# ::: {.content-visible when-format="pdf"}
# this is in the pdf
# ![](plot3d-fallback.png)
# :::

# %%
qshow(550 * (1 - (1 + 0.05)^-30) / 0.05)
# Out:
# $$ 8454.84806478556 $$

# %%
sqrt(8)
# Out:
# 2*sqrt(2)

# %%
N(Out[7])
# Out:
# 2.82842712474619

# %%
sqrt(3.4)
# Out:
# 1.84390889145858

# %%
n(pi)
# Out:
# 3.14159265358979

# %%
n(e)
# Out:
# 2.71828182845905

# %%
numerical_approx(sqrt(2), digits = 200)
# Out:
# 1.4142135623730950488016887242096980785696718753769480731766797379907324784621070388503875343276415727350138462309122970249248360558507372126441214970999358314132226659275055927557999505011527820605715

# %%
64^(1/6)
# Out:
# 2

# %%
N(sqrt(2), digits=10)
# Out:
# 1.414213562

# %%
true or false
# Out:
# True

# %%
sqrt(-1)
# Out:
# I

# %%
ln(e)
# Out:
# 1

# %%
ln(e^2)
# Out:
# 2

# %%
log(100)
# Out:
# 2*log(10)

# %%
log(10)
# Out:
# log(10)

# %%
N(log(10))
# Out:
# 2.30258509299405

# %%
N(log(100, 42))
# Out:
# 1.23209664210588

# %%
log(1.4, 1 + 0.045 / 12)
# Out:
# 89.8940609330801

# %%
log(1.4) / log(1 + 0.045 / 12)
# Out:
# 89.8940609330801

# %%
log(1 + 0.045 / 12)
# Out:
# 0.00374298627883430

# %%
Out[25] % 12
# Out:
# 5.89406093308006

# %%
Out[25]
# Out:
# 89.8940609330801

# %%
sqrt(4, all = True)
# Out:
# [2, -2]

# %%
sqrt(-4, all = True)
# Out:
# [2*I, -2*I]

# %%
sqrt(-4)
# Out:
# 2*I

# %%
print(sqrt(-4))
# Out:
# 2*I

# %%
print(log(1 + sqrt(20)))
# Out:
# log(2*sqrt(5) + 1)

# %%
latex(log(1 + sqrt(20)))
# Out:
# \log\left(2 \, \sqrt{5} + 1\right)

# %%
show(log(2 + sqrt(30)))
# Out:
# log(sqrt(30) + 2)

# %%
qshow(log(2 + sqrt(30)))
# Out:
# $$ \log\left(\sqrt{30} + 2\right) $$

# %%
sin(pi/3)
# Out:
# 1/2*sqrt(3)

# %%
n(sin(pi/3))
# Out:
# 0.866025403784439

# %%
tan(pi/2)
# Out:
# Infinity

# %%
cos(pi/12)
# Out:
# 1/4*sqrt(6) + 1/4*sqrt(2)

# %%
qshow(Out[48])
# Out:
# $$ \frac{1}{4} \, \sqrt{6} + \frac{1}{4} \, \sqrt{2} $$

# %%
arcsin(12)
# Out:
# arcsin(12)

# %%
arcsin(1/2)
# Out:
# 1/6*pi

# %%
plot(x^2)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(x^3)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(x^3 - x, -2, 2)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(x^4 - 3*x^2 + 2, -2, 2)

# %%
1 + 1
# Out:
# 2

# %%
plot(sin(x))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(x^3 - x, -2, 2)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(x^4 - 3*x^2 + 2, -2, 2)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(sin(x), -10, 10)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(sin(t))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 plot(sin(t))
#
# NameError: name 't' is not defined

# %%
plot(x^3, 5, 10)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(x^3, 5, 10, axes = False)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(x^3 - x, -3, 3)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(x^3 - x, -3, 3, ymin = -6, ymax =  6)
# Out:
# Graphics object consisting of 1 graphics primitive
